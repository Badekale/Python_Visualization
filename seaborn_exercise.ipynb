# %%
# import pandas
import pandas as pd
import numpy as np
# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv',sep=',')
df.drop('#',axis=1,inplace=True)

# %%
df.Generation.value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
gene1=df[df.Generation==1]
gene2=df[df.Generation==2]
gene3=df[df.Generation==3]
gene4=df[df.Generation==4]
gene5=df[df.Generation==5]
gene6=df[df.Generation==6]
gene6.head()
# Out:
#            Name Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 718     Chespin  Grass       NaN    313  56      61       65       48
# 719   Quilladin  Grass       NaN    405  61      78       95       56
# 720  Chesnaught  Grass  Fighting    530  88     107      122       74
# 721    Fennekin   Fire       NaN    307  40      45       40       62
# 722     Braixen   Fire       NaN    409  59      59       58       90
#
#      Sp. Def  Speed  Generation  Legendary
# 718       45     38           6      False
# 719       58     57           6      False
# 720       75     64           6      False
# 721       60     60           6      False
# 722       70     73           6      False

# %% [markdown]
# # Objective: Plot regression line between attack and defense

# %%
sns.set_style('whitegrid') 
sns.set(rc={'figure.figsize':(15,18)})
sns.lmplot(x ='Attack', y ='Defense', data = df)

# %% [markdown]
# # Objective: Plot regression line between attack and defense with respect to generation

# %%
sns.set_style('whitegrid') 
sns.lmplot(x ='Attack', y ='Defense',hue='Generation', data = df)

# %% [markdown]
# # Objective: Make boxplot for each feature of dataframe (without Generation and Legendary features) in one plot

# %%
df2 = pd.DataFrame(data = np.random.random(size=(4,4)), columns = ['A','B','C','D'])
df2
ff=pd.melt(df2)
# sns.boxplot(x="variable", y="value", data=pd.melt(df))

# plt.show()

# %%
df2
# Out:
#           A         B         C         D
# 0  0.723337  0.977417  0.213778  0.675064
# 1  0.188136  0.390204  0.472460  0.632851
# 2  0.621119  0.579934  0.887355  0.053967
# 3  0.032558  0.753566  0.739791  0.026589

# %%
ff.head()
# ff=ff.variable.reset_index()
ff=ff.set_index('variable')

# %%
ff.head()
# Out:
#              value
# variable
# A         0.723337
# A         0.188136
# A         0.621119
# A         0.032558
# B         0.977417

# %%
# ffgg=ff.pivot(index='' columns='value')
# ffgg
# Out:
#   File "<ipython-input-12-be538b99eb9b>", line 1
#     ffgg=ff.pivot(index='' columns='value')
#                                  ^
# SyntaxError: invalid syntax

# %%
heat.head()
# Out:
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    318  45      49       49       65       65     45
# 1    405  60      62       63       80       80     60
# 2    525  80      82       83      100      100     80
# 3    625  80     100      123      122      120     80
# 4    309  39      52       43       60       50     65

# %%
sns.boxplot(x="variable", y="value", data=pd.melt(heat))
plt.show()

# %%
# sns.set(style="white", color_codes=True)
# # a = sns.load_dataset("df")
# sns.boxplot(y=[,], data=df)
# # sns.boxplot(y=, data=df)
fig,((ax1, ax2),(ax3, ax4),(ax5, ax6),(ax7, ax8)) = plt.subplots(4,2,figsize=(20,15)) # not add axs while defining 

sns.boxplot( y = "Attack",data=df ,ax = ax1).set_title('Attack')
sns.boxplot( y = "Defense",data=df, ax = ax2).set_title('Defense')
sns.boxplot( y = "Sp. Atk",data=df, ax = ax3).set_title('Sp. Atk')
sns.boxplot( y = "HP",data=df, ax = ax4).set_title('HP')
sns.boxplot( y = "Total",data=df, ax = ax5).set_title('Total')
sns.boxplot( y = "Sp. Def",data=df, ax = ax6).set_title('Sp. Def')
sns.boxplot( y = "Speed",data=df, ax = ax7).set_title('Speed')
# Out:
# Text(0.5, 1.0, 'Speed')

# %% [markdown]
# # Objective: Plot correlation heatmap of pokemon dataframe (not include features Generation and Legendary)

# %%
df.head()

# %%
task=['Total', 'HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed']
heat=df[task]
heat.head()
# Out:
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    318  45      49       49       65       65     45
# 1    405  60      62       63       80       80     60
# 2    525  80      82       83      100      100     80
# 3    625  80     100      123      122      120     80
# 4    309  39      52       43       60       50     65

# %%
df_corr = heat.corr()

# plot the correlations
sns.heatmap(df_corr,annot=True,cmap="RdYlGn_r")
plt.title('Correlation plot')
plt.show

# %%
plt.plot(x=df_task8_distance.dep_time_hour[df_task8_distance.distance=='Short haul flight'],
         y= df_task8_distance.counter[df_task8_distance.distance=='Short haul flight'])
plt.show()
